# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
# from google.colab import files
# uploaded = files.upload()
# import io
# df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))

df = pd.read_csv('C:/Users/imran/OneDrive/Desktop/lesson notes/Employee-attrition.csv')

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Types of Data Frame

# %%
# A:

df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
print(df.dtypes.value_counts())
# Out:
# object    13
# int64      5
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Select the Job_Title column and check their values

# %%
# A:
df['job_title']
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B  Find the total no. of rows for each unique Job Title
#
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A:

df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Compensation Analyst                 20
# Investment Analyst                   20
# Systems Analyst                      20
# ...

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count [fill in blank]
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows =
#     return number_of_rows
# ```

# %%
def row_count(column_name):
    number_of_rows = column_name.count()
    return number_of_rows

# %%
#other answer:
def row_count(column_name):
    number_of_rows = len(df[column_name])
    return number_of_rows

row_count('job_title')
# Out:
# 49653

# %%
row_count(df['age'])
# Out:
# 49653

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:

print(np.mean(df['age']))
print(np.std(df['age']))
print(np.min(df['age']))
print(np.max(df['age']))
print(df['age'].count())
# Out:
# 42.077034620264634
# 12.427132257589273
# 19
# 65
# 49653

# %%
# other answer:
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
print(np.mean(df[::]))
print(np.std(df[::]))
print(np.min(df[::]))
print(np.max(df[::]))
print(df[::].count())
# Out:
# EmployeeID           4859.495740
# age                    42.077035
# length_of_service      10.434596
# store_name             27.297605
# STATUS_YEAR          2010.612612
# dtype: float64
# EmployeeID           1826.552748
# age                    12.427132
# length_of_service       6.325222
# store_name             13.513998
# STATUS_YEAR             2.845548
# dtype: float64
# EmployeeID                         1318
# recorddate_key            1/1/2006 0:00
# birthdate_key                  1/1/1946
# orighiredate_key               1/1/1990
# terminationdate_key            1/1/1900
# age                                  19
# length_of_service                     0
# city_name                    Abbotsford
# department_name              Accounting
# job_title              Accounting Clerk
# store_name                            1
# gender_short                          F
# gender_full                      Female
# termreason_desc                  Layoff
# ...

# %%
# other answer:
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Making The Index Meaningful

# %% [markdown]
# Set the index to be the column 'Employee ID'

# %%
# A:
df.set_index('EmployeeID',inplace=True)

# %%
df.head().T #employee id becomes index. 
#adding .T will transpose it. only changes how it appears but the dataframe remains the same
# Out:
# EmployeeID                      1318             1318             1318  \
# recorddate_key       12/31/2006 0:00  12/31/2007 0:00  12/31/2008 0:00
# birthdate_key               1/3/1954         1/3/1954         1/3/1954
# orighiredate_key           8/28/1989        8/28/1989        8/28/1989
# terminationdate_key         1/1/1900         1/1/1900         1/1/1900
# age                               52               53               54
# length_of_service                 17               18               19
# city_name                  Vancouver        Vancouver        Vancouver
# department_name            Executive        Executive        Executive
# job_title                        CEO              CEO              CEO
# store_name                        35               35               35
# gender_short                       M                M                M
# gender_full                     Male             Male             Male
# ...

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %% [markdown]
# e.g. (i) find row number 100 (ii) find employee_id # 8188

# %%
# A:

# (i) find row number 100

df.loc[[100]]

# (ii) find employee_id # 8188

df[df["EmployeeID"] == 8188]
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 47741        8188  12/31/2013 0:00    10/22/1993        4/25/2013
# 49643        8188   10/1/2014 0:00    10/22/1993        4/25/2013
#
#       terminationdate_key  age  length_of_service city_name   department_name  \
# 47741          10/25/2014   20                  0  Victoria  Customer Service
# 49643          10/25/2014   21                  1  Victoria  Customer Service
#
#       job_title  store_name gender_short gender_full termreason_desc  \
# 47741   Cashier          46            F      Female  Not Applicable
# 49643   Cashier          46            F      Female      Resignaton
#
#         termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 47741  Not Applicable         2013      ACTIVE        STORES
# 49643       Voluntary         2014  TERMINATED        STORES

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:

df.sort_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age in descending order

# %%
# A:

df.sort_values('age',ascending=True)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 48132        8325  12/31/2013 0:00     12/7/1994       11/29/2013
# 47925        8253  12/31/2013 0:00     5/15/1994        8/12/2013
# 47922        8252  12/31/2013 0:00     5/10/1994         8/9/2013
# 47919        8251  12/31/2013 0:00      5/7/1994         8/7/2013
# 47916        8250  12/31/2013 0:00     4/26/1994         8/2/2013
# ...           ...              ...           ...              ...
# 48635        3262    8/1/2008 0:00     8/23/1943        2/28/1995
# 48634        3248    8/1/2008 0:00     8/14/1943        2/19/1995
# 49127        4948    7/1/2013 0:00      7/9/1948        1/14/2000
# 48651        3356   11/1/2008 0:00    11/18/1943        5/26/1995
# 48820        4138    2/1/2011 0:00     2/12/1946        8/20/1997
#
#       terminationdate_key  age  length_of_service        city_name  \
# 48132            1/1/1900   19                  0        Cranbrook
# ...

# %% [markdown]
# #### 3.D [BONUS] Using 'Sample' Select Any Row

# %%
# A: 

df.sample()
# Out:
#       EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 8237        2777  12/31/2012 0:00      1/8/1957       11/21/1993
#
#      terminationdate_key  age  length_of_service city_name department_name  \
# 8237            1/1/1900   55                 19  Kamloops           Meats
#
#         job_title  store_name gender_short gender_full termreason_desc  \
# 8237  Meat Cutter          15            F      Female  Not Applicable
#
#        termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 8237  Not Applicable         2012  ACTIVE        STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:

df[df["job_title"] == 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# ...

# %% [markdown]
# #### 4.B Group By Age i.e the count of rows by each age

# %%
# A:

df.groupby(["age"], as_index=True)[["age"]].count()
# Out:
#       age
# age
# 19    158
# 20    408
# 21    703
# 22    815
# 23    960
# 24   1111
# 25   1197
# 26   1210
# 27   1235
# 28   1225
# 29   1227
# 30   1212
# 31   1146
# 32   1153
# 33   1164
# 34   1188
# 35   1189
# 36   1176
# 37   1149
# 38   1156
# 39   1142
# 40   1130
# 41   1135
# 42   1152
# 43   1150
# 44   1157
# 45   1141
# 46   1161
# 47   1173
# 48   1180
# 49   1196
# 50   1218
# 51   1207
# 52   1188
# 53   1188
# 54   1159
# 55   1168
# 56   1154
# 57   1130
# 58   1130
# 59   1128
# 60   1109
# 61    757
# 62    712
# 63    667
# 64    646
# 65    593

# %% [markdown]
# # 5. Visualization
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:

_=plt.hist(df['age'], bins=10)
_=plt.xlabel('Age')
_=plt.ylabel('Number of employees')

plt.show()

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:

_=plt.boxplot(df['age'])
_=plt.ylabel('Age')

plt.show()

# %% [markdown]
# #### 5.C Scatterplot of age vs. length_of_service

# %%
# A:

plt.scatter(df['length_of_service'], df['age'])
_=plt.xlabel('Length of service')
_=plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A:

_=plt.hist(df['store_name'])
_=plt.xlabel('Store Name')
_=plt.ylabel('No. of Stores')
plt.show()

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:

df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
