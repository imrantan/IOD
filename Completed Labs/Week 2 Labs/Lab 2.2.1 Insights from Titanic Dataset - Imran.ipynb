# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.1 Insights from Titanic Dataset
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# Read Titanic Dataset
titanic_csv = 'C:/Users/imran/OneDrive/Desktop/lesson notes/titanic.csv'
titanic = pd.read_csv(titanic_csv)

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every steps

# %% [markdown]
# ### Age

# %%
# ANSWER - my method

#calculate mean & median ages:

avg_age = titanic['Age'].mean()
median_age = titanic['Age'].median()

print('overall age avg: ', avg_age)
print('overall age median: ', median_age)

#calculate mean & median ages for respective sex:

female_pass = titanic[(titanic['Sex'] == 'female')]

avg_f_age = female_pass['Age'].mean()
median_f_age = female_pass['Age'].median()

print('female age avg: ', avg_f_age)
print('female age median: ', median_f_age)

male_pass = titanic[(titanic['Sex'] == 'male')]

avg_m_age = male_pass['Age'].mean()
median_m_age = male_pass['Age'].median()

print('male age avg: ', avg_m_age)
print('male age median: ', median_m_age)
# Out:
# overall age avg:  29.69911764705882
# overall age median:  28.0
# female age avg:  27.915708812260537
# female age median:  27.0
# male age avg:  30.72664459161148
# male age median:  29.0

# %%
#noted from the above that the median and mean for all the groups of people by gender is similar to the overall age.
#since all these values would fall under the same bin.

# %%
#titanic['Age'].fillna(avg_age, inplace = True)
#titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fareclass  Ageclass
# 0      0         A/5 21171   7.2500   NaN        S          4         2
# 1      0          PC 17599  71.2833   C85        C          1         4
# 2      0  STON/O2. 3101282   7.9250   NaN        S          4         3
# ...

# %%
#Answer - gregory's method

titanic['Age'].fillna(titanic.groupby(by=['Sex'])['Age'].transform("median"), inplace=True)

# %%
titanic['Age'] = titanic.groupby(['Pclass', 'Sex'])['Age'].apply(lambda x: x.fillna(x.mean()))
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Cabin

# %%
# ANSWER - my answer first method

titanic[(titanic['Cabin'].isnull() == True)]

#the cabin number will not affect our analysis below as it is not a variable which we are considering. 
# Hence to to just put as 'unknown'

#titanic['Cabin'].fillna('unknown', inplace = True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
.value_counts()titanic['Cabin']
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F2             3
# E101           3
#               ..
# C70            1
# C62 C64        1
# B37            1
# E58            1
# B69            1
# Name: Cabin, Length: 147, dtype: int64

# %%
titanic['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
titanic[(titanic['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[(titanic['Pclass'] == 2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male  29.0      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
import seaborn as sns


sns.boxplot(x='Pclass',y='Fare',data=titanic) 
plt.xticks(rotation=70) # rotates the xticks
plt.show()

# %%
titanic[(titanic['Pclass'] == 3)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic[(titanic['Pclass'] == 3)]['Cabin'].unique()
# Out:
# array([nan, 'G6', 'F G73', 'F E69', 'E10', 'F G63', 'E121', 'F38'],
#       dtype=object)

# %%
titanic[(titanic['Pclass'] == 2)]['Cabin'].unique()
# Out:
# array([nan, 'D56', 'F33', 'E101', 'F2', 'F4', 'D', 'E77'], dtype=object)

# %%
titanic[(titanic['Pclass'] == 1)]['Cabin'].unique()
# Out:
# array(['C85', 'C123', 'E46', 'C103', 'A6', 'C23 C25 C27', nan, 'B78',
#        'D33', 'B30', 'C52', 'B28', 'C83', 'E31', 'A5', 'D10 D12', 'D26',
#        'C110', 'B58 B60', 'D47', 'B86', 'C2', 'E33', 'B19', 'A7', 'C49',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66',
#        'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128',
#        'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30',
#        'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22',
#        'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20',
#        'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126',
#        'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'C62 C64', 'E24', 'C90',
# ...

# %%
pd.DataFrame(titanic.groupby(['Pclass', 'Sex'])['Age'])
# Out:
#              0                                                  1
# 0  (1, female)  1      38.0
# 3      35.0
# 11     58.0
# 31     27....
# 1    (1, male)  6      54.0
# 23     28.0
# 27     19.0
# 30     40....
# 2  (2, female)  9      14.0
# 15     55.0
# 41     27.0
# 43      3....
# 3    (2, male)  17     29.0
# 20     35.0
# 21     34.0
# 33     66....
# 4  (3, female)  2      26.0
# 8      27.0
# 10      4.0
# 14     14....
# 5    (3, male)  0      22.0
# 4      35.0
# 5      29.0
# 7       2....

# %% [markdown]
# ### Embarked

# %%
# ANSWER
titanic[(titanic['Embarked'].isnull() == True)]
# ANSWER

#We will require it for our analysis on the the no. of people who survived or did not survived from each respective point of embarkment
#hence, if it is unknown we could indicate that the information as 'X' for unknown. 
# only 2 passengers have unknown data, which will not significantly affect our analysis.

#titanic['Embarked'].fillna('X', inplace = True)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Ageclass
# 61   female  38.0      0      0  113572  80.0   B28      NaN         4
# 829  female  62.0      0      0  113572  80.0   B28      NaN         5

# %%
titanic[(titanic['Ticket'] == '11357')]
# Out:
#   File "<ipython-input-19-4870becb722a>", line 1
#     titanic[(titanic['Ticket'] == '11357'%)]
#                                           ^
# SyntaxError: invalid syntax

# %%
#check again for null values
titanic['Embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
# ANSWER
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)
    
    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %% [markdown]
# ## Pclass
#
# Use barchart to find relationship between survived and pclass.  Note your findings.

# %%
# ANSWER

bar_charts(titanic, 'Pclass')

# %% [markdown]
# Findings: Noted that that majority of the passengers in class 1 survived, whereas majority of passengers in class 2 and 3 did not survive. Noted that most of the passengers who did not survive belonged to class 3 and most of the passengers who suvived belong to class 1.
#
# Conclusion: Passengers in class 1 were more likely to survive than the other classes.

# %% [markdown]
# ## Sex
#
# Use barchart to find relationship between survived and sex.  Note your findings.

# %%
# ANSWER

bar_charts(titanic, 'Sex')

# %% [markdown]
# Findings: Noted that majority of the people who survived are females and the majority of people who did not survive are male. Also, the majority of females survived, while majority of the males did not.
#
# Conclusion: Females were more likely to survive than males.

# %% [markdown]
# ## Parch
#
# Parch = Number of parents of children travelling with each passenger.

# %%
# ANSWER

bar_charts(titanic, 'Parch')

# %% [markdown]
# Findings: Most people were travelling without their parents or children. The number of parents or children doesn't seem to indicate whether a person is more or less likely to surive. Hence, no strong correlation between the rate of survival with the no. of parents/children a person has.

# %% [markdown]
# ## SibSp
#
# Use barchart to find relationship between survived and SibSp. Note your findings.

# %%
# ANSWER


bar_charts(titanic, 'SibSp')

# %% [markdown]
# Findings: Most people were not travelling with their siblings or spouses. And all the people with 5 and 8 siblings/spouses did not survive. The number of siblings or spouses doesn't seem to indicate whether a person is more or less likely to surive. Hence, no strong correlation between the rate of survival with the no. of sibling/spouse a person has.

# %% [markdown]
# ## Embarked
#
# Use barchart to find relationship between survived and port of embarkation. Note your findings.

# %%
# ANSWER

bar_charts(titanic, 'Embarked')

# %% [markdown]
# Findings: Doesn't seem to indicate any strong correlation between the rate of survival with the passenger's point of embarkment.

# %% [markdown]
# # Feature Engineering
#
# Create some new features from existing feature.

# %% [markdown]
# ## Fare Class
#
# Create a new class (i.e. column 'FareClass') based on the following function applied to their fare. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
# ANSWER - first method

#fare = titanic['Fare']

#fare_class = [] #create empty list

#for x in fare: #loop the fucntion to fill the list
#    f_class = create_fare_class(x)
#    fare_class.append(f_class)

#titanic['Fareclass'] = fare_class #add list as a column in the dataframe

#titanic.head() #check if it has been added

# %%
#del titanic['Fareclass'] ---> to delete column

titanic['Fareclass'] = titanic['Fare'].apply(create_fare_class)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fareclass
# 0      0         A/5 21171   7.2500   NaN        S          4
# 1      0          PC 17599  71.2833   C85        C          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          4
# 3      0            113803  53.1000  C123        S          1
# ...

# %%
bar_charts(titanic, 'Fareclass') #run the analysis

# %% [markdown]
# Findings:
#
# - Majority of people in fareclass 1 survived
# - Slightly more people did not survie from fareclass 2 and 3
# - Majority of the people from class 4 did not surive

# %% [markdown]
# ## Age Class

# %%
# ANSWER

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
titanic['Ageclass'] = titanic['Age'].apply(create_age_class) #apply function and add the column for the new values
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fareclass  Ageclass
# 0      0         A/5 21171   7.2500   NaN        S          4         2
# 1      0          PC 17599  71.2833   C85        C          1         4
# 2      0  STON/O2. 3101282   7.9250   NaN        S          4         3
# ...

# %%
bar_charts(titanic, 'Ageclass') #run the analysis (i ran this before filling the values)

# %%
bar_charts(titanic, 'Ageclass') #run the analysis

# %% [markdown]
# Findings: Across all age groups, majority of the people did not survive except for the age group 1 (less than 16 yrs old).

# %% [markdown]
# # Statistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.035734 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.073296 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.338056  0.083081  0.018443
# Age             0.035734 -0.073296 -0.338056  1.000000 -0.236376 -0.176038
# SibSp          -0.057527 -0.035322  0.083081 -0.236376  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.176038  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.094161  0.159651  0.216225
# Fareclass       0.003258 -0.307600  0.719670 -0.113032 -0.380692 -0.387100
# Ageclass        0.026653 -0.067911 -0.292128  0.928753 -0.232166 -0.168121
#
#                  Fare  Fareclass  Ageclass
# PassengerId  0.012658   0.003258  0.026653
# Survived     0.257307  -0.307600 -0.067911
# Pclass      -0.549500   0.719670 -0.292128
# Age          0.094161  -0.113032  0.928753
# ...

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# The usual process of null hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the p-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the p-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data (samples), one with the passenger greater than 35 years of age and another one with the passenger younger than 35. The sample size should ideally be the same but it can be different. Lets say that the sample sizes is N = 100.

# %%
# ANSWER

titanic_young = titanic[(titanic['Age'] <= 35)].sample(100)

titanic_old = titanic[(titanic['Age'] > 35)].sample(100)

# %% [markdown]
# ### Set alpha (let alpha = 0.05)
#
# > Identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
# ANSWER

alpha = 0.05

# %% [markdown]
# ### Calculate point estimate

# %%
a = titanic_young['Survived']
b = titanic_old['Survived']

# %%
## Calculate the variance to get the standard deviation
var_a = a.var(ddof = 1)
var_b = b.var(ddof = 1)

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)

# %% [markdown]
# ### Calculate test statistic

# %%
## Calculate the t-statistic
t = (a.mean() - b.mean())/(s*np.sqrt(2/100))

# %% [markdown]
# ### Find the p-value
#
# > Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
from scipy import stats

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*100 - 2

#p-value after comparison with the t 
if (t > 0):
    p = 1 - stats.t.cdf(t, df = df) 
else:
    p = stats.t.cdf(t, df = df)

# %%
print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# t = -0.2885537149744704
# p = 0.7732247764980036

# %% [markdown]
# ### Interpret results
#
# > Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
    else:
        print("Our test is inconclusive.")

# %%
print_sig(p, alpha)
# Out:
# We fail to reject our null hypothesis.

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)
# Out:
# t = -0.2885537149744703
# p = 0.7732247764980036
# We fail to reject our null hypothesis.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
