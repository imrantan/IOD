# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.2 Linear Regression II

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Find Dependent and Independent Variables to predict house price.

# %%
# Read CSV
house_csv = "house_new.csv"
house = pd.read_csv(house_csv)
house.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude  \
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768
#
#    actual_minus_average_price  predicted_house_prices      residuals
# 0               170962.965347           135519.056164  -76297.056164
# 1               161972.965347           176838.917832 -108626.917832
# 2               161304.965347           130525.719406  -61645.719406
# 3               160877.965347           137516.390867  -68209.390867
# 4               148284.965347           130650.552825  -48750.552825

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %%
# ANSWER

# %% [markdown]
# #### 2.2 List all possible variables which might be Independent/Predictor variable.

# %%
# ANSWER

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER

house.corr()
# Out:
#                                  zip      beds     baths        sq__ft  \
# zip                         1.000000 -0.066559 -0.101562 -1.015033e-01
# beds                       -0.066559  1.000000  0.653577  6.963678e-01
# baths                      -0.101562  0.653577  1.000000  7.240098e-01
# sq__ft                     -0.101503  0.696368  0.724010  1.000000e+00
# price                      -0.219807  0.440803  0.500008  6.923043e-01
# latitude                   -0.131302 -0.111139 -0.082901 -1.027984e-01
# longitude                  -0.561654  0.053003  0.106334  1.349291e-01
# actual_minus_average_price -0.047382  0.090064  0.167118  3.591270e-01
# predicted_house_prices     -0.101503  0.696368  0.724010  1.000000e+00
# residuals                  -0.207227 -0.057227 -0.001701  3.818377e-16
#
#                                price  latitude  longitude  \
# zip                        -0.219807 -0.131302  -0.561654
# beds                        0.440803 -0.111139   0.053003
# baths                       0.500008 -0.082901   0.106334
# sq__ft                      0.692304 -0.102798   0.134929
# price                       1.000000  0.060049   0.277623
# latitude                    0.060049  1.000000   0.343975
# longitude                   0.277623  0.343975   1.000000
# actual_minus_average_price  0.529938  0.059697   0.151425
# predicted_house_prices      0.692304 -0.102798   0.134929
# residuals                   0.721606  0.181840   0.255279
#
#                             actual_minus_average_price  \
# zip                                          -0.047382
# beds                                          0.090064
# baths                                         0.167118
# sq__ft                                        0.359127
# price                                         0.529938
# latitude                                      0.059697
# longitude                                     0.151425
# actual_minus_average_price                    1.000000
# predicted_house_prices                        0.359127
# residuals                                     0.389843
#
#                             predicted_house_prices     residuals
# zip                                  -1.015033e-01 -2.072269e-01
# beds                                  6.963678e-01 -5.722686e-02
# baths                                 7.240098e-01 -1.700851e-03
# sq__ft                                1.000000e+00  3.818377e-16
# price                                 6.923043e-01  7.216056e-01
# latitude                             -1.027984e-01  1.818402e-01
# longitude                             1.349291e-01  2.552786e-01
# actual_minus_average_price            3.591270e-01  3.898433e-01
# predicted_house_prices                1.000000e+00  4.401658e-16
# residuals                             4.401658e-16  1.000000e+00

# %% [markdown]
# #### 2.4 Find Coefficient and Intercept using Linear Regression
#
# Using LinearRegression of sklearn.linear_model package find Coefficient and Intercept.
#
# Create an instance of LinearRegression.
#
# Explore following methods:
#
# - fit
# - predict
# - score

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### 2.4.1 Fit predictor and target variables using linear regression

# %%
# ANSWER

X = house['sq__ft'].values.reshape(-1,1)
Y = house['price']

# %% [markdown]
# ##### 2.4.2 Find R Score

# %% [markdown]
# Find $R^2$ Using ```score``` method of Linear Regression.

# %%
# ANSWER

reg = LinearRegression().fit(X, Y)
reg.score(X, Y)
# Out:
# 0.4792852861969368

# %% [markdown]
# ### 3. Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 3.1 Create training and testing subsets
#
# Hint: Using `train_test_split` Library.
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ```

# %%
# ANSWER
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[1428],
#        [1170],
#        [1828],
#        [ 588],
#        [1419],
#        [1991],
#        [2235],
#        [1130],
#        [1788],
#        [ 970],
#        [1810],
#        [1183],
#        [ 779],
#        [1103],
#        [1315],
#        [1381],
#        [1232],
#        [3357],
#        [1354],
#        [2347],
#        [ 911],
#        [1266],
#        [1120],
#        [ 881],
#        [1051],
#        [1440],
#        [1628],
#        [1229],
#        [1590],
#        [1416],
#        [1132],
#        [3009],
#        [2800],
#        [1150],
#        [1326],
#        [2960],
#        [2508],
#        [1559],
#        [1488],
#        [1859],
#        [1517],
#        [1064],
#        [1292],
#        [1289],
#        [1159],
#        [1043],
#        [1056],
#        [1110],
#        [1058],
#        [1520],
#        [3863],
#        [1202],
#        [1240],
#        [1200],
#        [ 994],
#        [1328],
#        [1202],
#        [2205],
#        [1451],
#        [1416],
#        [1134],
#        [ 852],
#        [1245],
#        [1981],
#        [1140],
#        [ 756],
#        [2711],
#        [3788],
#        [1904],
#        [1940],
#        [1676],
#        [1366],
#        [2172],
#        [1146],
#        [1527],
#        [1240],
#        [1475],
#        [1093],
#        [3579],
#        [1319],
#        [1040],
#        [1300],
#        [1655],
#        [1829],
#        [1595],
#        [1843],
#        [1273],
#        [1152],
#        [1120],
#        [1929],
#        [1117],
#        [3134],
#        [2605],
#        [1337],
#        [1596],
#        [1683],
#        [ 846],
#        [1247],
#        [2162],
#        [1264],
#        [1104],
#        [3260],
#        [2170],
#        [ 958],
#        [3261],
#        [3516],
#        [3134],
#        [2372],
#        [2846],
#        [1567],
#        [ 836],
#        [1358],
#        [ 924],
#        [1092],
#        [ 900],
#        [2581],
#        [2280],
#        [2367],
#        [1503],
#        [1144],
#        [1713],
#        [1358],
#        [2724],
#        [1144],
#        [1269],
#        [1179],
#        [1390],
#        [1578],
#        [1691],
#        [2354],
#        [1636],
#        [1118],
#        [ 611],
#        [1820],
#        [2056],
#        [3389],
#        [2992],
#        [1446]], dtype=int64)

# %%
X_test
# Out:
# array([[4400],
#        [ 932],
#        [1291],
#        [1139],
#        [1669],
#        [1627],
#        [1740],
#        [2169],
#        [2442],
#        [2306],
#        [1586],
#        [1176],
#        [1650],
#        [1477],
#        [1735],
#        [2724],
#        [1457],
#        [1126],
#        [2212],
#        [1483],
#        [3615],
#        [1362],
#        [1162],
#        [1039],
#        [ 760],
#        [1039],
#        [1187],
#        [1393],
#        [1289],
#        [1616],
#        [1082],
#        [1144],
#        [1410],
#        [1401],
#        [1206],
#        [1601],
#        [ 990],
#        [1375],
#        [1479],
#        [1156],
#        [1280],
#        [1118],
#        [1329],
#        [2052],
#        [1917],
#        [1953],
#        [1711],
#        [ 904],
#        [1250],
#        [1127],
#        [1209],
#        [1306],
#        [1637],
#        [1795],
#        [ 888],
#        [2056],
#        [2652],
#        [2163],
#        [1329],
#        [1174],
#        [ 998],
#        [2367],
#        [2725],
#        [1264],
#        [1358],
#        [ 888],
#        [1120],
#        [1477],
#        [1541],
#        [ 924],
#        [1253],
#        [1011],
#        [2254],
#        [2280],
#        [1116],
#        [1152],
#        [1094],
#        [1019],
#        [1104],
#        [1856],
#        [1799],
#        [1510],
#        [1939],
#        [ 936],
#        [2136],
#        [ 682],
#        [1890],
#        [1798],
#        [2258],
#        [1477],
#        [3670],
#        [1182],
#        [1590],
#        [ 972],
#        [1120],
#        [1616],
#        [ 625],
#        [2575],
#        [1899],
#        [ 723],
#        [1341],
#        [1185],
#        [1204],
#        [2026],
#        [1258],
#        [ 832],
#        [1018],
#        [1468],
#        [1341],
#        [1555],
#        [1543],
#        [1175],
#        [ 948],
#        [1876],
#        [1928],
#        [1582],
#        [2093],
#        [ 909],
#        [1309],
#        [2213],
#        [3070],
#        [1166],
#        [1360],
#        [2002],
#        [1174],
#        [1029],
#        [1914],
#        [ 956],
#        [1317],
#        [1248],
#        [1188],
#        [1638],
#        [1039],
#        [ 795],
#        [1277],
#        [1089],
#        [2166],
#        [1410],
#        [1252],
#        [1758],
#        [1800],
#        [1182],
#        [3746],
#        [1265],
#        [1462],
#        [3397],
#        [1177],
#        [1354],
#        [2372],
#        [1080],
#        [2085],
#        [1000],
#        [1032],
#        [ 796],
#        [1450],
#        [1115],
#        [ 960],
#        [2877],
#        [2295],
#        [1177],
#        [1232],
#        [1400],
#        [1882],
#        [1382],
#        [3468],
#        [ 795],
#        [1624],
#        [1373],
#        [1478],
#        [ 840],
#        [2109],
#        [1428],
#        [ 958],
#        [2457],
#        [1659],
#        [2484],
#        [1627],
#        [1406],
#        [1751],
#        [ 904],
#        [1406],
#        [1157],
#        [1676],
#        [ 988],
#        [1082],
#        [1258],
#        [1127],
#        [2199],
#        [1939],
#        [1215],
#        [ 984],
#        [2555],
#        [1159],
#        [ 696],
#        [2346],
#        [1580],
#        [2494],
#        [1516],
#        [2159],
#        [1250],
#        [1305],
#        [ 840],
#        [1188],
#        [1176],
#        [1353],
#        [1724],
#        [ 722],
#        [1266],
#        [3984],
#        [2054],
#        [1587],
#        [1715],
#        [2096],
#        [1720],
#        [1549],
#        [1712],
#        [2846],
#        [1448],
#        [1098],
#        [ 967],
#        [1380],
#        [1443],
#        [1321],
#        [1158],
#        [2962],
#        [1685],
#        [2359],
#        [1124],
#        [1448],
#        [2687],
#        [1351],
#        [1104],
#        [1410],
#        [2085],
#        [ 780],
#        [1511],
#        [1327],
#        [2295],
#        [2325],
#        [1462],
#        [1574],
#        [1605],
#        [2100],
#        [1410],
#        [1830],
#        [2356],
#        [1013],
#        [1851],
#        [1340],
#        [1922],
#        [1207],
#        [1269],
#        [1857],
#        [1457],
#        [1943],
#        [2789],
#        [1092],
#        [1740],
#        [ 901],
#        [1624],
#        [1300],
#        [2660],
#        [1590],
#        [1587],
#        [1302],
#        [1595],
#        [1436]], dtype=int64)

# %%
y_train
# Out:
# 762    188700
# 544    176250
# 615    250000
# 18     120000
# 588    220000
#         ...
# 71     200000
# 106    285000
# 270    370000
# 435    295000
# 102    275086
# Name: price, Length: 541, dtype: int64

# %%
y_test
# Out:
# 697    884790
# 296     65000
# 227    236250
# 336    133105
# 537    168750
#         ...
# 51     173000
# 334    127500
# 741    157500
# 264    339000
# 361    180000
# Name: price, Length: 267, dtype: int64

# %% [markdown]
# #### 3.2 Check Shape, Sample of Test Train Data

# %%
# ANSWER
## Check training/test data

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (541, 1)
# (541,)
# (267, 1)
# (267,)

# %% [markdown]
# #### 3.3 Using Linear Regression Find The Score
#
# 1. Fit model using X_train, y_train
# 2. Find score using X_test, y_test

# %%
# ANSWER

reg = LinearRegression().fit(X_train, y_train)
reg.score(X_train, y_train)
# Out:
# 0.4713873668902573

# %%
# ANSWER

reg.score(X_test, y_test)
# Out:
# 0.48808261753470117

# %% [markdown]
# ### 4. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house using linear regression model.**

# %%
# ANSWER

reg.predict([[1204,]])
# Out:
# array([182495.035267])

# %%
reg.coef_
# Out:
# array([129.13348618])

# %%
reg.intercept_
# Out:
# 27221.196073751926

# %%
reg.coef_*1204 + reg.intercept_
# Out:
# array([182495.035267])

# %% [markdown]
# #### Find the error (Mean Squared Error)

# %%
# Predict price from X_test

from sklearn.metrics import mean_squared_error

mean_squared_error(X_test, y_test)
# Out:
# 68086847562.52809

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
